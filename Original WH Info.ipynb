# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\Esther\OneDrive\Desktop\rhoda\order.xls")

# %%
df
# Out:
#   Order.NO       CustomerPo origin stock source                  Product  \
# 0  Z479080     20210414-SLK     --          USA     S8499,KRpep-2d,5mg,1
# 1  Z479078              NaN     --          USA    S6734,PF-670462,5mg,1
# 2  Z479076              NaN     --          USA  S2775,Nocodazole,50mg,1
# 3  Z479007  1850 N YC006 00     --          USA      S7342,UNC2250,5mg,1
# 4      NaN              NaN    NaN          NaN   S7213,Thiamet G ,5mg,1
#
#     quantity        weight       DCountry                Delivery Company  \
# 0  01-14支,\n   01-935mg,\n  United States    Reaction Biology Corporation
# 1        NaN           NaN  United States        Florida State University
# 2   01-6支,\n  01-6088mg,\n  United States                    Notable Labs
# 3  01-17支,\n  01-4710mg,\n  United States  UCLA JULES STEIN EYE INSTITUTE
# 4   02-3支,\n   01-218mg,\n            NaN                             NaN
#
#    Coupon Delivery Condition  Catalog  发票随货  冰盒  笔记本         积分卡  定制礼品
# ...
